# %%
df = spark.read.format("csv").option("inferSchema", "true").option("header", "true").load(
    "/mnt/clx-datalake/landing/testing/Cricketers.csv"
)
df.spark.write.mode("overwrite").saveAsTable("raw.cricketers")
